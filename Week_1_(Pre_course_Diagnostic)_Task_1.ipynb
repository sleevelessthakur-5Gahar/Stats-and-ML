# %%
data = [12, 15, 14, 10, 18, 20, 17, 16, 14, 13]
print(data)
# Out:
# [12, 15, 14, 10, 18, 20, 17, 16, 14, 13]

# %% [markdown]
# The aforementioned line of code will print the dataset provided.

# %%
lowest=data[0]
for i in data:
  if i < lowest:
    lowest=i
print(f"The lowest value is : {lowest}")
# Out:
# The lowest value is : 10

# %%
sorting=sorted(data)
print(f"Sorted data set is: {sorting}")
# Out:
# Sorted data set is: [10, 12, 13, 14, 14, 15, 16, 17, 18, 20]

# %%
highest=data[0]
for i in data:
  if i > highest:
    highest=i
print(f"The highest value is : {highest}")
# Out:
# The highest value is : 20

# %%
x=0
y=0
for i in data:
  x+=i
  y+=1
mean=x/y
print(f"Mean is: {mean}")
# Out:
# Mean is: 14.9

# %%
length=len(data)
if length%2 == 0:
  median=(data[length//2-1]+data[length//2])/2
else:
  median=data[length//2]
print(f"Median is: {median}")
# Out:
# Median is: 19.0

# %%
frequency = {}

for num in data:
    frequency[num] = frequency.get(num, 0) + 1

max_frequency = max(frequency.values())

most_frequent = []
for num in frequency:
    if frequency[num] == max_frequency:
        most_frequent.append(num)

print("Most frequent value(s):", most_frequent)
# Out:
# Most frequent value(s): [14]
